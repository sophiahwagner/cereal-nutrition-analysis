# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style='darkgrid')

# %%
import pandas as pd
cereal_df = pd.read_csv('cereal.csv')
cereal_df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
cereal_df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
### Top 5 cereals with the most amount of sugar per serving

# %%
cereal_df.sort_values('sugars',ascending=False).head()
# Out:
#                      name mfr type  calories  protein  fat  sodium  fiber  \
# 66                 Smacks   K    C       110        2    1      70    1.0
# 30           Golden Crisp   P    C       100        2    0      45    0.0
# 70      Total Raisin Bran   G    C       140        3    1     190    4.0
# 52  Post Nat. Raisin Bran   P    C       120        3    1     200    6.0
# 6             Apple Jacks   K    C       110        2    0     125    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 66    9.0      15      40        25      2    1.00  0.75  31.230054
# 30   11.0      15      40        25      1    1.00  0.88  35.252444
# 70   15.0      14     230       100      3    1.50  1.00  28.592785
# 52   11.0      14     260        25      3    1.33  0.67  37.840594
# 6    11.0      14      30        25      2    1.00  1.00  33.174094

# %%
cereal_df['sugar_per_cup']=cereal_df['sugars']/cereal_df['cups']

# %%
### Top 5 cereals with the most sugar per cup (using new variable sugar_per_cup)

# %%
cereal_df.sort_values('sugar_per_cup',ascending=False).head(5)
# Out:
#                      name mfr type  calories  protein  fat  sodium  fiber  \
# 52  Post Nat. Raisin Bran   P    C       120        3    1     200    6.0
# 66                 Smacks   K    C       110        2    1      70    1.0
# 51   Oatmeal Raisin Crisp   G    C       130        3    2     170    1.5
# 46   Mueslix Crispy Blend   K    C       160        3    2     150    3.0
# 0               100% Bran   N    C        70        4    1     130   10.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 52   11.0      14     260        25      3    1.33  0.67  37.840594
# 66    9.0      15      40        25      2    1.00  0.75  31.230054
# 51   13.5      10     120        25      3    1.25  0.50  30.450843
# 46   17.0      13     160        25      3    1.50  0.67  30.313351
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
#
#     sugar_per_cup  protein_cal  protein_percent
# 52      20.895522           12        10.000000
# ...

# %%
cereal_df['protein_cal']=cereal_df['protein']*4

# %%
cereal_df['protein_percent']=cereal_df['protein_cal']/cereal_df['calories']*100

# %%
high_protein_df=cereal_df[cereal_df['protein_percent']>=20]

# %%
### Top 5 cereals with the highest percent of calories from protein (using new variable protein_percent)

# %%
high_protein_df.sort_values('protein_percent',ascending=False).head()
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 11                   Cheerios   G    C       110        6    2     290    2.0
# 67                  Special K   K    C       110        6    0     230    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 11   17.0       1     105        25      1     1.0  1.25  50.764999
# 67   16.0       3      55        25      1     1.0  1.00  53.131324
#
#     sugar_per_cup  protein_cal  protein_percent
# ...

# %%
mfr_df = cereal_df.groupby('mfr').mean(numeric_only=True)

# %%
### Highest amount of sugar per cup by cereal manufacturer

# %%
mfr_df.sort_values('sugar_per_cup',ascending=False)
# Out:
#        calories   protein       fat      sodium     fiber      carbo  \
# mfr
# P    108.888889  2.444444  0.888889  146.111111  2.777778  13.222222
# K    108.695652  2.652174  0.608696  174.782609  2.739130  15.130435
# G    111.363636  2.318182  1.363636  200.454545  1.272727  14.727273
# R    115.000000  2.500000  1.250000  198.125000  1.875000  17.625000
# Q     95.000000  2.625000  1.750000   92.500000  1.337500  10.000000
# N     86.666667  2.833333  0.166667   37.500000  4.000000  16.000000
# A    100.000000  4.000000  1.000000    0.000000  0.000000  16.000000
#
#        sugars      potass   vitamins     shelf    weight      cups     rating  \
# mfr
# P    8.777778  113.888889  25.000000  2.444444  1.064444  0.714444  41.705744
# K    7.565217  103.043478  34.782609  2.347826  1.077826  0.796087  44.038462
# G    7.954545   85.227273  35.227273  2.136364  1.049091  0.875000  34.485852
# R    6.125000   89.250000  25.000000  2.000000  1.000000  0.871250  41.542997
# ...

# %%
### Bar chart showing average sugar per cup based on manufacturer. According to the chart, P (Post) had the highest average amount of sugar.

# %%
mfr_df['sugar_per_cup'].sort_values().plot(kind='bar',title='Average Sugar per Cup by Manufacturer',ylabel='Grams of Sugar',xlabel='Manufacturer',color='blue')
# Out:
# <Axes: title={'center': 'Average Sugar per Cup by Manufacturer'}, xlabel='Manufacturer', ylabel='Grams of Sugar'>

# %%
shelf_df = cereal_df.groupby('shelf').mean(numeric_only=True)

# %%
### Cereal is sorted by shelf number where it is displayed in stores to determine which shelf holds the cereals with the highest amount of sugar per cup

# %%
shelf_df.sort_values('sugar_per_cup', ascending=False).head()
# Out:
#          calories   protein   fat      sodium     fiber      carbo    sugars  \
# shelf
# 2      109.523810  1.904762  1.00  145.714286  0.904762  13.619048  9.619048
# 3      107.777778  2.861111  1.25  158.611111  3.138889  14.500000  6.527778
# 1      102.500000  2.650000  0.60  176.250000  1.685000  15.800000  4.800000
#
#            potass   vitamins    weight      cups     rating  sugar_per_cup  \
# shelf
# 2       57.809524  23.809524  1.015714  0.911429  34.972827      11.101812
# 3      129.833333  35.416667  1.058889  0.726111  45.220032      10.097624
# 1       75.500000  20.000000  0.991500  0.897000  46.145439       5.591317
#
#        protein_cal  protein_percent
# shelf
# 2         7.619048         7.130351
# 3        11.444444        11.371386
# 1        10.600000        10.405051

# %%
### Bar chart shows that shelves 2 and 3 hold cereals with a higher number of grams of sugar per cup on average than shelf 1

# %%
shelf_df['sugar_per_cup'].sort_values().plot(kind='bar',title='Average Suger Per Cup by Shelf Number',xlabel='Shelf',ylabel='Sugar per cup',color='purple')
# Out:
# <Axes: title={'center': 'Average Suger Per Cup by Shelf Number'}, xlabel='Shelf', ylabel='Sugar per cup'>

# %%
negative = cereal_df[cereal_df['sugars'] == -1]

# %%
### Faulty data value (-1g of sugar) isolated

# %%
negative
# Out:
#               name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 57  Quaker Oatmeal   Q    H       100        5    2       0    2.7   -1.0
#
#     sugars  potass  vitamins  shelf  weight  cups     rating  sugar_per_cup  \
# 57      -1     110         0      1     1.0  0.67  50.828392      -1.492537
#
#     protein_cal  protein_percent
# 57           20             20.0

# %%
healthy_kids_df = cereal_df[(cereal_df['mfr'].isin (['K','G']))&(cereal_df['sugars']<8)&(cereal_df['fiber']>=3)]

# %%
### Healthy cereals are defined as those produced by Kellogs (K) or General Mills (G) with less than 8g of sugar and at least 3g of Fiber. They are sorted below in a table and bar chart based on fiber content.

# %%
healthy_kids_df.sort_values('fiber', ascending=False).head()
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 19         Cracklin' Oat Bran   K    C       110        3    3     140    4.0
# 26        Frosted Mini-Wheats   K    C       100        3    0       0    3.0
# 49  Nutri-Grain Almond-Raisin   K    C       140        3    2     220    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 3     8.0       0     330        25      3    1.00  0.50  93.704912
# 2     7.0       5     320        25      3    1.00  0.33  59.425505
# 19   10.0       7     160        25      3    1.00  0.50  40.448772
# 26   14.0       7     100        25      2    1.00  0.80  58.345141
# 49   21.0       7     130        25      3    1.33  0.67  40.692320
#
#     sugar_per_cup  protein_cal  protein_percent
# ...

# %%
healthy_kids_df['fiber'].sort_values().plot(kind = 'bar', title='Healthiest cereal', ylabel='Grams of fiber',color='blue')
# Out:
# <Axes: title={'center': 'Healthiest cereal'}, ylabel='Grams of fiber'>

# %%
### Finding: Sugar vs. Ratings
### The graph below shows the impact of grams per sugar per serving on a product's consumer rating score. It shows a noticeable negative correlation between the two, such that as grams of sugar increases, consumer rating score, in general, decreases.

# %%
sns.scatterplot(data=cereal_df, x='sugars', y='rating',hue='mfr', palette='muted', s=50,alpha=0.8)
plt.title("Impact of Sugar on Consumer Ratings",fontsize=14,weight='bold')
plt.xlabel("Grams of Sugar per Serving")
plt.ylabel("Consumer Rating Score")
# Out:
# Text(0, 0.5, 'Consumer Rating Score')

# %%
### Determining whether a relationship exists between grams of sugar and grams of carbohydrtes'
### No correlation between the two; cereals exist in all ranges and a cereal higher in complex carbs does not necessarily have l ower sugar

# %%
sns.scatterplot(cereal_df,x='carbo',y='sugars',hue='mfr',palette='muted')
plt.title("Relationship Between Sugar and Carbohydrates",fontsize=12,weight='bold')
plt.xlabel("Grams of Carbohydrates per Serving")
plt.ylabel("Grams of Sugar per serving")
# Out:
# Text(0, 0.5, 'Grams of Sugar per serving')

# %%
plt.figure(figsize = (9,5))

# %%
sns.histplot(data=cereal_df,x='calories',bins=15,kde=True,color='teal')
plt.title("Full Market Distribution: Calories per Serving",fontsize=14,weight='bold')
plt.xlabel("Calories")
plt.ylabel("Number of Cereals")
# Out:
# Text(0, 0.5, 'Number of Cereals')

# %%
plt.figure(figsize=(9,5))
sns.boxplot(data=cereal_df,x='shelf',y='fiber')
plt.title("Fiber Content by Retail Shelf",fontsize=14,weight='bold')
plt.xlabel("Shelf Placement (1 = Bottom, 2 = Middle, 3 = Top)")
plt.ylabel("Grams of Fiber per Serving")
# Out:
# Text(0, 0.5, 'Grams of Fiber per Serving')

# %%
numeric_df=cereal_df.select_dtypes(include='number')

# %%
numeric_df
# Out:
#     calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 0         70        4    1     130   10.0    5.0       6     280        25
# 1        120        3    5      15    2.0    8.0       8     135         0
# 2         70        4    1     260    9.0    7.0       5     320        25
# 3         50        4    0     140   14.0    8.0       0     330        25
# 4        110        2    2     200    1.0   14.0       8      -1        25
# ..       ...      ...  ...     ...    ...    ...     ...     ...       ...
# 72       110        2    1     250    0.0   21.0       3      60        25
# 73       110        1    1     140    0.0   13.0      12      25        25
# 74       100        3    1     230    3.0   17.0       3     115        25
# 75       100        3    1     200    3.0   17.0       3     110        25
# 76       110        2    1     200    1.0   16.0       8      60        25
#
#     shelf  weight  cups     rating
# ...

# %%
numeric_df.corr()
# Out:
#           calories   protein       fat    sodium     fiber     carbo  \
# calories  1.000000  0.019066  0.498610  0.300649 -0.293413  0.250681
# protein   0.019066  1.000000  0.208431 -0.054674  0.500330 -0.130864
# fat       0.498610  0.208431  1.000000 -0.005407  0.016719 -0.318043
# sodium    0.300649 -0.054674 -0.005407  1.000000 -0.070675  0.355983
# fiber    -0.293413  0.500330  0.016719 -0.070675  1.000000 -0.356083
# carbo     0.250681 -0.130864 -0.318043  0.355983 -0.356083  1.000000
# sugars    0.562340 -0.329142  0.270819  0.101451 -0.141205 -0.331665
# potass   -0.066609  0.549407  0.193279 -0.032603  0.903374 -0.349685
# vitamins  0.265356  0.007335 -0.031156  0.361477 -0.032243  0.258148
# shelf     0.097234  0.133865  0.263691 -0.069719  0.297539 -0.101790
# weight    0.696091  0.216158  0.214625  0.308576  0.247226  0.135136
# cups      0.087200 -0.244469 -0.175892  0.119665 -0.513061  0.363932
# rating   -0.689376  0.470618 -0.409284 -0.401295  0.584160  0.052055
#
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(numeric_df.corr(),annot=True,cmap='coolwarm',fmt=".2f")
plt.title("Variable Correlation for Top 80 Cereals", fontsize='14',weight='bold')
plt.show()

# %%
# testing git staging
